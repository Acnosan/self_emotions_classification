# %%
import tensorflow as tf

# %%
tf.config.list_logical_devices()
print(tf.__version__)
# Out:
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'),
#  LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
from IPython.display import Audio, display
import numpy as np

def notify_sound():
    # Generate a beep sound (can adjust frequency and duration)
    framerate = 44100  # Hz
    duration = 0.5  # seconds
    frequency = 440  # A4 note in Hz

    t = np.linspace(0, duration, int(framerate * duration))
    wave = 0.5 * np.sin(2 * np.pi * frequency * t)

    display(Audio(wave, rate=framerate, autoplay=True))

# %%
notify_sound()
# Out:
#         <audio autoplay>
#             <source src="data:audio/wav;base64,..." type="audio/wav">
#             Your browser does not support the audio element.
#         </audio>

# %%
from IPython.display import display, HTML

# Your long-running code here
# ...

# At the end of your code
display(HTML("<h1 style='color: green;'>Execution complete! 🎉</h1>"))
# Out:
# <h1 style='color: green;'>Execution complete! 🎉</h1>
